# %%
from mmdt_tokenizer import MyanmarTokenizer
from mmdt_tokenizer.utils.config import DATA_DIR, OUTPUT_DIR
from pathlib import Path


tokenizer = MyanmarTokenizer()

# %%
def test_merge_days(tokenizer):
    # Case 1: unseen + Day + [PUNCT] + CL -- Combine to one phrase
    # Case 2: Day 
    # Case 3: 
 
    text = [["ကြာသပတေးနေ့တွင် ကြာပန်း ၅ ခိုင်ယူလာကြပါ။"], 
            ["ကဆုန် လပြည့်နေ့တွင် ရေသပ္ပာယ်မည်။"] ,
            ["လပြည့်သည် လူအမည်လည်း ဖြစ်နိုင်ပါသည်။"]]
            
    tokens = tokenizer.word_tokenize(text)
    print(tokens)

test_merge_days(tokenizer)
# Out:
# [Chunk(span=(0, 4), text='ကြာသပတေးနေ့', tag='DAYCL'), Chunk(span=(5, 5), text='တွင်', tag='POSTP'), Chunk(span=(6, 6), text=' ', tag='PUNCT'), Chunk(span=(7, 7), text='ကြာ', tag='RAW'), Chunk(span=(8, 8), text='ပန်း', tag='RAW'), Chunk(span=(9, 9), text=' ', tag='PUNCT'), Chunk(span=(10, 12), text='၅ခိုင်', tag='NUMCL'), Chunk(span=(13, 13), text='ယူ', tag='RAW'), Chunk(span=(14, 14), text='လာ', tag='VEP'), Chunk(span=(15, 15), text='ကြ', tag='VEP'), Chunk(span=(16, 16), text='ပါ', tag='SFP'), Chunk(span=(17, 17), text=' ', tag='PUNCT'), Chunk(span=(18, 18), text='။', tag='PUNCT'), Chunk(span=(19, 19), text=' ', tag='PUNCT')]
# [Chunk(span=(0, 1), text='ကဆုန်', tag='MONTH'), Chunk(span=(2, 2), text=' ', tag='PUNCT'), Chunk(span=(3, 5), text='လပြည့်နေ့', tag='DAYCL'), Chunk(span=(6, 6), text='တွင်', tag='POSTP'), Chunk(span=(7, 7), text=' ', tag='PUNCT'), Chunk(span=(8, 8), text='ရေသပ္ပာယ်မည်။', tag='PARLI')]
# [Chunk(span=(0, 1), text='လပြည့်', tag='DAY'), Chunk(span=(2, 2), text='သည်', tag='SFP'), Chunk(span=(3, 3), text=' ', tag='PUNCT'), Chunk(span=(4, 4), text='လူ', tag='RAW'), Chunk(span=(5, 5), text='အ', tag='RAW'), Chunk(span=(6, 6), text='မည်', tag='SFP'), Chunk(span=(7, 7), text='လည်း', tag='CONJ'), Chunk(span=(8, 8), text=' ', tag='PUNCT'), Chunk(span=(9, 9), text='ဖြစ်', tag='RAW'), Chunk(span=(10, 10), text='နိုင်', tag='VEP'), Chunk(span=(11, 11), text='ပါ', tag='SFP'), Chunk(span=(12, 12), text='သည်', tag='SFP'), Chunk(span=(13, 13), text=' ', tag='PUNCT'), Chunk(span=(14, 14), text='။', tag='PUNCT'), Chunk(span=(15, 15), text=' ', tag='PUNCT')]
# ['ကြာသပတေးနေ့တွင် ', 'ကြာပန်း', '၅ခိုင်', 'ယူ', 'လာကြပါ', '။', 'ကဆုန်', 'လပြည့်နေ့တွင် ', 'ရေသပ္ပာယ်မည်။', '။', 'လပြည့်သည်', 'လူအ', 'မည်', 'လည်း ', 'ဖြစ်', 'နိုင်ပါသည်', '။']

# %%
def test_merge_numbers(tokenizer):
    # Case 1: unseen + NUMBER/ word Number + [PUNCT] + CL -- Combine to one phrase
    # Case 2: unseen + Word Number + UNSEEN -- Combine number as one 
    # Case 3: unseen + Number
 
    text = [["လူဦးရေ ၁၉၆,၀၀၀ အနက် ရာခိုင်နှုန်း၃၀ မှာ အသက် ၁၅ နှစ်အောက် ဖြစ်ကြသည်။"],
            ["တစ်ရာ သုံးဆယ့် ငါး ဦးမှာ မိန်းမများ ဖြစ်ပြီး ၃ရာမှာ ကလေးများ ဖြစ်သည်"],
            ["လူမျိုးစု ၅ စုသည် နှစ်ပေါင်းများစွာ အတူတကွ နေထိုင်ခဲ့ကြသည်"],
            ['၅၀ ရာခိုင်နှုန်း ']]
            
    tokens = tokenizer.word_tokenize(text)
    print(tokens)

test_merge_numbers(tokenizer)
# Out:
# [Chunk(span=(0, 0), text='လူဦး', tag='RAW'), Chunk(span=(1, 1), text='ရေ', tag='RAW'), Chunk(span=(2, 2), text=' ', tag='PUNCT'), Chunk(span=(3, 3), text='၁၉၆,၀၀၀', tag='NUM'), Chunk(span=(4, 5), text='အနက်', tag='CONJ'), Chunk(span=(6, 6), text=' ', tag='PUNCT'), Chunk(span=(7, 7), text='ရာခိုင်နှုန်း', tag='NUMCL'), Chunk(span=(8, 10), text='၃၀', tag='NUM'), Chunk(span=(11, 11), text='မှာ', tag='POSTP'), Chunk(span=(12, 12), text=' ', tag='PUNCT'), Chunk(span=(13, 13), text='အ', tag='RAW'), Chunk(span=(14, 14), text='သက်', tag='RAW'), Chunk(span=(15, 15), text=' ', tag='PUNCT'), Chunk(span=(16, 20), text='၁၅နှစ်အောက်', tag='NUMCL'), Chunk(span=(21, 21), text=' ', tag='PUNCT'), Chunk(span=(22, 22), text='ဖြစ်', tag='RAW'), Chunk(span=(23, 23), text='ကြ', tag='VEP'), Chunk(span=(24, 24), text='သည်', tag='SFP'), Chunk(span=(25, 25), text=' ', tag='PUNCT'), Chunk(span=(26, 26), text='။', tag='PUNCT'), Chunk(span=(27, 27), text=' ', tag='PUNCT')]
# [Chunk(span=(0, 7), text='တစ်ရာသုံးဆယ့်ငါးဦး', tag='NUMCL'), Chunk(span=(8, 8), text='မှာ', tag='POSTP'), Chunk(span=(9, 9), text=' ', tag='PUNCT'), Chunk(span=(10, 11), text='မိန်းမ', tag='PRN'), Chunk(span=(12, 12), text='များ', tag='CL'), Chunk(span=(13, 13), text=' ', tag='PUNCT'), Chunk(span=(14, 15), text='ဖြစ်ပြီး', tag='CONJ'), Chunk(span=(16, 16), text=' ', tag='PUNCT'), Chunk(span=(17, 18), text='၃ရာ', tag='NUM'), Chunk(span=(19, 19), text='မှာ', tag='POSTP'), Chunk(span=(20, 20), text=' ', tag='PUNCT'), Chunk(span=(21, 22), text='ကလေး', tag='PRN'), Chunk(span=(23, 23), text='များ', tag='CL'), Chunk(span=(24, 24), text=' ', tag='PUNCT'), Chunk(span=(25, 26), text='ဖြစ်သည်', tag='SFP'), Chunk(span=(27, 27), text=' ', tag='PUNCT')]
# [Chunk(span=(0, 0), text='လူ', tag='RAW'), Chunk(span=(1, 1), text='မျိုး', tag='CL'), Chunk(span=(2, 2), text='စု', tag='CL'), Chunk(span=(3, 3), text=' ', tag='PUNCT'), Chunk(span=(4, 6), text='၅စု', tag='NUMCL'), Chunk(span=(7, 7), text='သည်', tag='SFP'), Chunk(span=(8, 8), text=' ', tag='PUNCT'), Chunk(span=(9, 9), text='နှစ်', tag='WORDNUM'), Chunk(span=(10, 10), text='ပေါင်း', tag='RAW'), Chunk(span=(11, 11), text='များ', tag='CL'), Chunk(span=(12, 12), text='စွာ', tag='RAW'), Chunk(span=(13, 13), text=' ', tag='PUNCT'), Chunk(span=(14, 14), text='အ', tag='RAW'), Chunk(span=(15, 15), text='တူ', tag='RAW'), Chunk(span=(16, 16), text='တ', tag='RAW'), Chunk(span=(17, 17), text='ကွ', tag='RAW'), Chunk(span=(18, 18), text=' ', tag='PUNCT'), Chunk(span=(19, 19), text='နေ', tag='VEP'), Chunk(span=(20, 20), text='ထိုင်', tag='RAW'), Chunk(span=(21, 22), text='ခဲ့ကြ', tag='VEP'), Chunk(span=(23, 23), text='သည်', tag='SFP'), Chunk(span=(24, 24), text=' ', tag='PUNCT')]
# [Chunk(span=(0, 3), text='၅၀ရာခိုင်နှုန်း', tag='NUM')]
# ['လူဦးရေ', '၁၉၆,၀၀၀', 'အနက် ', 'ရာခိုင်နှုန်း', '၃၀မှာ ', 'အသက်', '၁၅နှစ်အောက်', 'ဖြစ်', 'ကြသည်', '။', 'တစ်ရာသုံးဆယ့်ငါးဦးမှာ ', 'မိန်းမများ', 'ဖြစ်ပြီး ', '၃ရာမှာ ', 'ကလေးများဖြစ်သည်', '။', 'လူမျိုးစု', '၅စု', 'သည်နှစ်ပေါင်းများစွာအတူတကွ', 'နေထိုင်', 'ခဲ့ကြသည်', '။', '၅၀ရာခိုင်နှုန်း', '။']

# %%
def test_merge_predicate(tokenizer):
    # Case 1: unseen + VEP + SFP -- split to raw , pred if more than 5, else keep it as one pred
    # Case 2: unseen + Conj + [unseen]+ [VEP] + SFP
    # Case 3: Negatiave Phrase -- Neg_Prefix + [VEP]+[VEP]+... + NEG_SFP
    # Case 4: Question Phrase -- Que_Presfix + [VEP]+[VEP]+... + QUE_SFP
 
    text = [["အကြိမ်ရေစိပ်လာပါတယ်","စုစည်း တက်ရောက် ခဲ့ကြပါသည်။","အရှင်ဖမ်းမိခဲ့တဲ့ တိုက်ပွဲဖြစ်တယ်","ကြိုးစားရိုးသားစေချင်ပါတယ်။", "ရိုးသားစေချင်ပါတယ်။"],
            ["အပြည့်စုံကိုမသူဇာလင်းကပြောပြပေးသွားမှာပါ", "ဝန်ထမ်းတွေလည်းအဲဒီအချိန်ကတည်းကစက်ရုံကိုစွန့်ခွာသွားတာဖြစ်ပါတယ်။", "ကြိုးစားသော်လည်း စာမေးပွဲကျပါသည်", "ကြိုးစားနေကြပါတယ်ဟုမဆိုနိုင်ပါ"],
            ["သူမ စိတ်ဆိုးနေတယ်မနေဘူးက မည်သူမျှမသိပါဘူး။", "အစီအစဥ်ကို သူမစိတ်ဆိုး မနေပါဘူး", "သူမစိတ်ဆိုးမနေပါဘူး",
              "စိတ်မ၀င်စားပါ",  "အိမ်မက် မမက်ပါနဲ့"],
            ["ပူးပေါင်းမှု ဘာသဘောဆောင်လဲ", "သူတို့ ဘာကြောင့်အသက်ဆုံးရှုံးခဲ့ရသလဲ"]]
            
    tokens = tokenizer.word_tokenize(text[2][1])
    print(tokens)

test_merge_predicate(tokenizer)
# Out:
# [Chunk(span=(0, 0), text='အ', tag='RAW'), Chunk(span=(1, 1), text='စီ', tag='CL'), Chunk(span=(2, 2), text='အ', tag='RAW'), Chunk(span=(3, 3), text='စဥ်', tag='RAW'), Chunk(span=(4, 4), text='ကို', tag='POSTP'), Chunk(span=(5, 5), text=' ', tag='PUNCT'), Chunk(span=(6, 7), text='သူမ', tag='PRN'), Chunk(span=(8, 8), text='စိတ်', tag='RAW'), Chunk(span=(9, 9), text='ဆိုး', tag='RAW'), Chunk(span=(10, 10), text=' ', tag='PUNCT'), Chunk(span=(11, 11), text='မ', tag='RAW'), Chunk(span=(12, 12), text='နေ', tag='VEP'), Chunk(span=(13, 13), text='ပါ', tag='SFP'), Chunk(span=(14, 14), text='ဘူး', tag='SFP'), Chunk(span=(15, 15), text=' ', tag='PUNCT')]
# ['အစီအစဥ်ကို သူမစိတ်ဆိုး', 'မနေပါဘူး', '။']

# %%
def test_tagging_csv(tokenizer):
    """Tests the CSV loading/saving feature exposed by the main tokenizer."""
    csv_text_path = OUTPUT_DIR / "result_word_text.csv"
    csv_output_path = OUTPUT_DIR / "result_word_tag.csv"
    text = [["ကြာသပတေးနေ့တွင် ကြာပန်း ၅ ခိုင်ယူလာကြပါ။"], 
            ["ကဆုန် လပြည့်နေ့တွင် ရေသပ္ပာယ်မည်။"] ,
            ["လပြည့်"],["လူဦးရေ ၁၉၆,၀၀၀ အနက် ရာခိုင်နှုန်း၃၀ မှာ အသက် ၁၅ နှစ်အောက် ဖြစ်ကြသည်။"],
            ["တစ်ရာ သုံးဆယ့် ငါး ဦးမှာ မိန်းမများ ဖြစ်ပြီး ၃ရာမှာ ကလေးများ ဖြစ်သည်ဟု ဦး၀င်းမောင်ဦးက ပြောသည်"],
            ["လူမျိုးစု ၅ စုသည် နှစ်ပေါင်းများစွာ အတူတကွ နေထိုင်ခဲ့ကြသည်"],
            ['ရာခိုင်နှုန်း ၃၀ '],
            ["စုစည်း တက်ရောက်ခဲ့ကြပါတော့သည်။","စုစည်း တက်ရောက် ခဲ့ကြပါသည်။","စုစည်းတက်ရောက်ခဲ့ကြပါတော့သည်။","ကြိုးစားရိုးသားစေချင်ပါတယ်။", "ရိုးသားစေချင်ပါတယ်။"],
            ["စုစည်း တက်ရောက်ရန် ဖြစ်ကြသည်။", "ကြိုးစားသော်လည်း စာမေးပွဲကျပါသည်", "ကြိုးစားနေကြပါတယ်ဟုမဆိုနိုင်ပါ"],
            ["သူမ စိတ်ဆိုးနေတယ်မနေဘူးက မည်သူမျှမသိပါဘူး။", "အစီအစဥ်ကို သူမစိတ်ဆိုး မနေပါဘူး", "သူမစိတ်ဆိုးမနေပါဘူး", "စိတ်မ၀င်စားပါ",  "အိမ်မက် မမက်ပါနဲ့"]]
            
    tokens = tokenizer.word_tokenize(text,save_csv=str(csv_text_path), save_tag=str(csv_output_path), conll_style=False)

    assert Path(csv_output_path).exists()

test_tagging_csv(tokenizer)

# %%
import pandas as pd
def test_tagging_csv_input(tokenizer):
    """Tests the CSV loading/saving feature exposed by the main tokenizer."""
    csv_input_path = DATA_DIR /"test_data.csv" 
    csv_text_path = OUTPUT_DIR / "result_word_text.csv"
    csv_output_path = OUTPUT_DIR / "result_word_tag.csv"

    df = pd.read_csv(csv_input_path)
    
    tokenizer.word_tokenize(df,column = 'original_sentence', 
                                     save_csv=str(csv_text_path), save_tag=str(csv_output_path), conll_style=False)

    assert Path(csv_output_path).exists()

test_tagging_csv_input(tokenizer)
